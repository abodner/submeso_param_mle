# %%
# load netcdf from OM4 runs

import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr
import xgcm 
import cartopy.crs as ccrs
from matplotlib.colorbar import ColorbarBase
import cftime
import nc_time_axis

# %%
# paths to dataset
BASE = '/scratch/ab10313/OM4_output/'

# load FK temp data 
theta_avg_FK_1 = xr.open_dataset(BASE+'cntrl/ocean_annual_z.2003-2007.ann.nc').thetao_xyave.mean(['z_l'],skipna=True)
theta_avg_FK_2 = xr.open_dataset(BASE+'cntrl/ocean_annual_z.2008-2012.ann.nc').thetao_xyave.mean(['z_l'],skipna=True)
theta_avg_FK_3 = xr.open_dataset(BASE+'cntrl/ocean_annual_z.2013-2017.ann.nc').thetao_xyave.mean(['z_l'],skipna=True)
theta_avg_FK_4 = xr.open_dataset(BASE+'cntrl/ocean_annual_z.2018-2022.ann.nc').thetao_xyave.mean(['z_l'],skipna=True)

# concat into one timeseries
theta_avg_FK = xr.concat([theta_avg_FK_1, theta_avg_FK_2, theta_avg_FK_3, theta_avg_FK_4], "time")

'''
# load BD tos data 
ds_tos_BD_1 = xr.open_dataset(BASE+'c30/ocean_monthly.200301-200712.tos.nc')
ds_tos_BD_2 = xr.open_dataset(BASE+'c30/ocean_monthly.200801-201212.tos.nc')
ds_tos_BD_3 = xr.open_dataset(BASE+'c30/ocean_monthly.201301-201712.tos.nc')
ds_tos_BD_4 = xr.open_dataset(BASE+'c30/ocean_monthly.201801-202212.tos.nc')

# concat into one timeseries
ds_tos_BD = xr.concat([ds_tos_BD_1, ds_tos_BD_2, ds_tos_BD_3, ds_tos_BD_4], "time")

# take global mean
tos_BD = ds_tos_BD.tos.mean(['xh','yh'],skipna=True)
'''
# load static file
ds_stat = xr.open_dataset(BASE+'ocean_annual_z.static.nc')

# %%
xr.open_dataset(BASE+'cntrl/ocean_annual_z.2003-2007.ann.nc').time
# Out:
# <xarray.DataArray 'time' (time: 1)>
# array([cftime.DatetimeJulian(2005, 7, 2, 0, 0, 0, 0, has_year_zero=False)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 2005-07-02 00:00:00
# Attributes:
#     long_name:      time
#     axis:           T
#     calendar_type:  JULIAN
#     bounds:         time_bnds

# %%
theta_avg_FK.time

# %% [markdown]
# ## plot tos timeseries

# %%
theta_avg_FK.plot( )
#tos_BD.plot( )
