# %%
# load netcdf from OM4 runs

import numpy as np
import matplotlib.pyplot as plt
import os
import xarray as xr
import xgcm 
import cartopy.crs as ccrs
from matplotlib.colorbar import ColorbarBase

# %%
# !pip install xoverturning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xoverturning in /home/ab10313/.local/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: numpy in /home/ab10313/.local/lib/python3.9/site-packages (from xoverturning) (1.22.4)
# Requirement already satisfied: setuptools>=41.2 in /ext3/miniconda3/lib/python3.9/site-packages (from xoverturning) (63.4.1)
# Requirement already satisfied: xarray in /ext3/miniconda3/lib/python3.9/site-packages (from xoverturning) (2022.6.0)
# Requirement already satisfied: cmip-basins in /home/ab10313/.local/lib/python3.9/site-packages (from xoverturning) (1.0.5)
# Requirement already satisfied: scipy in /ext3/miniconda3/lib/python3.9/site-packages (from xoverturning) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in /ext3/miniconda3/lib/python3.9/site-packages (from xarray->xoverturning) (21.3)
# Requirement already satisfied: pandas>=1.2 in /ext3/miniconda3/lib/python3.9/site-packages (from xarray->xoverturning) (1.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /ext3/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->xarray->xoverturning) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /ext3/miniconda3/lib/python3.9/site-packages (from pandas>=1.2->xarray->xoverturning) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /ext3/miniconda3/lib/python3.9/site-packages (from pandas>=1.2->xarray->xoverturning) (2.8.2)
# Requirement already satisfied: six>=1.5 in /ext3/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->xarray->xoverturning) (1.16.0)

# %%
# !pip install regionmask
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: regionmask in /home/ab10313/.local/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: geopandas>=0.10 in /home/ab10313/.local/lib/python3.9/site-packages (from regionmask) (0.14.4)
# Requirement already satisfied: rasterio>=1.2 in /home/ab10313/.local/lib/python3.9/site-packages (from regionmask) (1.3.10)
# Requirement already satisfied: xarray>=0.20 in /ext3/miniconda3/lib/python3.9/site-packages (from regionmask) (2022.6.0)
# Requirement already satisfied: numpy>=1.21 in /home/ab10313/.local/lib/python3.9/site-packages (from regionmask) (1.22.4)
# Requirement already satisfied: pooch>=1.4 in /home/ab10313/.local/lib/python3.9/site-packages (from regionmask) (1.8.1)
# Requirement already satisfied: packaging>=21.3 in /ext3/miniconda3/lib/python3.9/site-packages (from regionmask) (21.3)
# Requirement already satisfied: shapely>=1.8 in /ext3/miniconda3/lib/python3.9/site-packages (from regionmask) (1.8.1)
# Requirement already satisfied: pandas>=1.4.0 in /ext3/miniconda3/lib/python3.9/site-packages (from geopandas>=0.10->regionmask) (1.4.4)
# Requirement already satisfied: pyproj>=3.3.0 in /home/ab10313/.local/lib/python3.9/site-packages (from geopandas>=0.10->regionmask) (3.6.0)
# Requirement already satisfied: fiona>=1.8.21 in /home/ab10313/.local/lib/python3.9/site-packages (from geopandas>=0.10->regionmask) (1.9.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /ext3/miniconda3/lib/python3.9/site-packages (from packaging>=21.3->regionmask) (3.0.9)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/ab10313/.local/lib/python3.9/site-packages (from pooch>=1.4->regionmask) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /ext3/miniconda3/lib/python3.9/site-packages (from pooch>=1.4->regionmask) (2.28.1)
# Requirement already satisfied: cligj>=0.5 in /home/ab10313/.local/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (0.7.2)
# Requirement already satisfied: importlib-metadata in /ext3/miniconda3/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (4.12.0)
# Requirement already satisfied: affine in /home/ab10313/.local/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (2.4.0)
# Requirement already satisfied: certifi in /ext3/miniconda3/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (2022.9.14)
# Requirement already satisfied: attrs in /ext3/miniconda3/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (22.1.0)
# Requirement already satisfied: setuptools in /ext3/miniconda3/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (63.4.1)
# Requirement already satisfied: snuggs>=1.4.1 in /home/ab10313/.local/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (1.4.7)
# Requirement already satisfied: click-plugins in /home/ab10313/.local/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (1.1.1)
# Requirement already satisfied: click>=4.0 in /ext3/miniconda3/lib/python3.9/site-packages (from rasterio>=1.2->regionmask) (8.1.3)
# Requirement already satisfied: six in /ext3/miniconda3/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas>=0.10->regionmask) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /ext3/miniconda3/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas>=0.10->regionmask) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /ext3/miniconda3/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas>=0.10->regionmask) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /ext3/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.4->regionmask) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /ext3/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.4->regionmask) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /ext3/miniconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.4->regionmask) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in /ext3/miniconda3/lib/python3.9/site-packages (from importlib-metadata->rasterio>=1.2->regionmask) (3.8.1)

# %%
# paths to dataset
BASE = '/scratch/ab10313/OM4_output/'

# load FK data for MOC calculation

ds_ann_FK = xr.open_dataset(BASE+'cntrl/ocean_annual_z.2018-2022.ann.nc')
ds_moc_FK = xr.merge([ds_ann_FK.umo, ds_ann_FK.vmo, ds_ann_FK.uhml, ds_ann_FK.vhml])

# load FK data for MOC calculation

ds_ann_BD = xr.open_dataset(BASE+'c30/ocean_annual_z.2018-2022.ann-004.nc')
ds_moc_BD = xr.merge([ds_ann_BD.umo, ds_ann_BD.vmo, ds_ann_BD.uhml, ds_ann_BD.vhml])

# load static file
ds_stat = xr.open_dataset(BASE+'ocean_annual_z.static.nc')

# %%
from xoverturning import calcmoc

# %%
# calculate global MOC
amoc_FK = calcmoc(ds_moc_FK, dsgrid=ds_ann_FK,basin='atl-arc')
amoc_BD = calcmoc(ds_moc_BD, dsgrid=ds_stat,basin='atl-arc')
# Out:
# generating basin codes
# generating basin codes

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, figsize=(6,8), dpi=600)

ax=ax.flatten()


i_ax = 0
amoc_FK.mean('time').rename('$\Psi_{\mathrm{AMOC}}$').plot(ax=ax[i_ax], yincrease=False,vmin=-15,vmax=15,cmap='RdBu_r',cbar_kwargs={'ticks': np.arange(-15,20,5)})
amoc_FK.mean('time').rename('$\Psi_{\mathrm{AMOC}}$').plot.contour(ax=ax[i_ax], yincrease=False, levels=np.concatenate([np.arange(-15,0,2),np.arange(2,15,2)]),
                      colors='k', linewidths=1)
ax[i_ax].set_ylim([5500,0])
ax[i_ax].set_xlim([-34,70])
ax[i_ax].set_title('a)  BFF11, AMOC')
ax[i_ax].set_ylabel('Depth [m]')
ax[i_ax].set_xlabel('')
ax[i_ax].set_xticks([])

i_ax = 1
amoc_BD.mean('time').rename('$\Psi_{\mathrm{AMOC}}$').plot(ax=ax[i_ax], yincrease=False,vmin=-15,vmax=15,cmap='RdBu_r',cbar_kwargs={'ticks': np.arange(-15,20,5)})
amoc_BD.mean('time').rename('$\Psi_{\mathrm{AMOC}}$').plot.contour(ax=ax[i_ax], yincrease=False, levels=np.concatenate([np.arange(-15,0,2),np.arange(2,15,2)]),
                      colors='k', linewidths=1)
ax[i_ax].set_ylim([5500,0])
ax[i_ax].set_xlim([-34,70])
ax[i_ax].set_title('b)  BOD23, AMOC')
ax[i_ax].set_ylabel('Depth [m]')
ax[i_ax].set_xlabel('')
ax[i_ax].set_xticks([])


i_ax = 2
(amoc_BD - amoc_FK).mean('time').rename('$\Psi_{\mathrm{AMOC}}$').plot(ax=ax[i_ax], yincrease=False,vmin=-2,vmax=2,cmap='RdBu_r',cbar_kwargs={'ticks': np.arange(-2,2.1,1)})
(amoc_BD - amoc_FK).mean('time').rename('$\Psi_{\mathrm{AMOC}}$').plot.contour(ax=ax[i_ax], yincrease=False, levels=np.concatenate([np.arange(-2,0,.5),np.arange(.1,2.5,.5)]),
                      colors='k', linewidths=1)
ax[i_ax].set_ylim([5500,0])
ax[i_ax].set_xlim([-34,70])
ax[i_ax].set_title('c)  BOD23- BFF11, AMOC')
ax[i_ax].set_ylabel('Depth [m]')
ax[i_ax].set_xlabel('Latitude')


# save figure
plt.savefig('./figures/AMOC_streamfunc')
